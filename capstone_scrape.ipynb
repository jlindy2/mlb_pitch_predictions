# %%
from pybaseball import statcast
import pandas as pd

# %%
#scrape 2019 pitch-by-pitch data

df19 = statcast(start_dt='2019-03-25', end_dt='2019-10-30')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2019-03-25 to 2019-03-30
# Completed sub-query from 2019-03-31 to 2019-04-05
# Completed sub-query from 2019-04-06 to 2019-04-11
# Completed sub-query from 2019-04-12 to 2019-04-17
# Completed sub-query from 2019-04-18 to 2019-04-23
# Completed sub-query from 2019-04-24 to 2019-04-29
# Completed sub-query from 2019-04-30 to 2019-05-05
# Completed sub-query from 2019-05-06 to 2019-05-11
# Completed sub-query from 2019-05-12 to 2019-05-17
# Completed sub-query from 2019-05-18 to 2019-05-23
# Completed sub-query from 2019-05-24 to 2019-05-29
# Completed sub-query from 2019-05-30 to 2019-06-04
# Completed sub-query from 2019-06-05 to 2019-06-10
# Completed sub-query from 2019-06-11 to 2019-06-16
# Completed sub-query from 2019-06-17 to 2019-06-22
# Completed sub-query from 2019-06-23 to 2019-06-28
# Completed sub-query from 2019-06-29 to 2019-07-04
# Completed sub-query from 2019-07-05 to 2019-07-10
# ...

# %%
df19.head()
# Out:
#    index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         SL 2019-10-30           87.9        -2.6489         5.5022
# 1      1         FF 2019-10-30           95.9        -2.7721         5.5161
# 2      2         FF 2019-10-30           96.5        -2.6782         5.4191
# 3      3         FF 2019-10-30           96.0        -2.6479         5.5516
# 4      4         SL 2019-10-30           86.7        -2.7268         5.5882
#
#      player_name    batter   pitcher     events  ... home_score  away_score  \
# 0  Daniel Hudson  488726.0  543339.0  strikeout  ...        2.0         6.0
# 1  Daniel Hudson  488726.0  543339.0        NaN  ...        2.0         6.0
# 2  Daniel Hudson  488726.0  543339.0        NaN  ...        2.0         6.0
# 3  Daniel Hudson  488726.0  543339.0        NaN  ...        2.0         6.0
# 4  Daniel Hudson  488726.0  543339.0        NaN  ...        2.0         6.0
#
# ...

# %%
df19.shape
# Out:
# (742883, 90)

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742883 entries, 0 to 742882
# Data columns (total 90 columns):
# index                              742883 non-null int64
# pitch_type                         740501 non-null object
# game_date                          742883 non-null datetime64[ns]
# release_speed                      738747 non-null float64
# release_pos_x                      738723 non-null float64
# release_pos_z                      738723 non-null float64
# player_name                        742883 non-null object
# batter                             742883 non-null float64
# pitcher                            742883 non-null float64
# events                             188683 non-null object
# description                        742883 non-null object
# spin_dir                           0 non-null float64
# spin_rate_deprecated               0 non-null float64
# break_angle_deprecated             0 non-null float64
# ...

# %%
#scrape 2018 pitch-by-pitch data

df18 = statcast(start_dt='2018-03-25', end_dt='2018-10-30')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-03-25 to 2018-03-30
# Completed sub-query from 2018-03-31 to 2018-04-05
# Completed sub-query from 2018-04-06 to 2018-04-11
# Completed sub-query from 2018-04-12 to 2018-04-17
# Completed sub-query from 2018-04-18 to 2018-04-23
# Completed sub-query from 2018-04-24 to 2018-04-29
# Completed sub-query from 2018-04-30 to 2018-05-05
# Completed sub-query from 2018-05-06 to 2018-05-11
# Completed sub-query from 2018-05-12 to 2018-05-17
# Completed sub-query from 2018-05-18 to 2018-05-23
# Completed sub-query from 2018-05-24 to 2018-05-29
# Completed sub-query from 2018-05-30 to 2018-06-04
# Completed sub-query from 2018-06-05 to 2018-06-10
# Completed sub-query from 2018-06-11 to 2018-06-16
# Completed sub-query from 2018-06-17 to 2018-06-22
# Completed sub-query from 2018-06-23 to 2018-06-28
# Completed sub-query from 2018-06-29 to 2018-07-04
# Completed sub-query from 2018-07-05 to 2018-07-10
# ...

# %%
df18.shape
# Out:
# (731207, 90)

# %%
# combine 2018 and 2019

df = pd.concat([df18, df19]).reset_index()

# %%
df.shape
# Out:
# (1474090, 91)

# %%
df.tail()
# Out:
#          level_0  index pitch_type  game_date  release_speed  release_pos_x  \
# 1474085   742878  10749         CH 2019-03-28           88.0        -2.8687
# 1474086   742879  10757         FF 2019-03-28           96.4        -2.7735
# 1474087   742880  10770         CH 2019-03-28           88.6        -2.8765
# 1474088   742881  10782         FF 2019-03-28           95.8        -2.7622
# 1474089   742882  10800         FF 2019-03-28           96.0        -2.9039
#
#          release_pos_z    player_name    batter   pitcher  ... home_score  \
# 1474085         4.9348  Luis Castillo  466320.0  622491.0  ...        0.0
# 1474086         5.2440  Luis Castillo  466320.0  622491.0  ...        0.0
# 1474087         5.0955  Luis Castillo  466320.0  622491.0  ...        0.0
# 1474088         5.1903  Luis Castillo  466320.0  622491.0  ...        0.0
# 1474089         5.2153  Luis Castillo  624428.0  622491.0  ...        0.0
#
# ...

# %%
df_baseball = df

# %%
# pickle original dataset
import pickle

df_baseball.to_pickle("df_baseball.pkl")

# %%
# drop useless columns
df_baseball.drop(['spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 
         'des', 'tfs_deprecated', 'tfs_zulu_deprecated', 'umpire', 
        'hc_x', 'hc_y', 'level_0', 'index'], axis=1, inplace=True)

# %%
# drop fielders
df_baseball.drop(['fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 
         'fielder_9'], axis=1, inplace=True)

# %%
# drop hitting results
df_baseball.drop(['hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed', 'release_spin_rate', 
        'release_extension', 'release_pos_y', 'estimated_ba_using_speedangle', 
        'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 
        'iso_value', 'launch_speed_angle'], axis=1, inplace=True)

# %%
# drop pitchfx
df_baseball.drop(['release_speed', 'release_pos_x', 'pfx_x', 'pfx_z', 
         'plate_x', 'plate_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 
         'sz_top', 'sz_bot'], axis=1, inplace=True)

# %%
cap_df = df_baseball

# %%
cap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1474090 entries, 0 to 1474089
# Data columns (total 44 columns):
# pitch_type               1468951 non-null object
# game_date                1474090 non-null datetime64[ns]
# release_pos_z            1467034 non-null float64
# player_name              1474090 non-null object
# batter                   1474090 non-null float64
# pitcher                  1474090 non-null float64
# events                   375845 non-null object
# description              1474090 non-null object
# zone                     1467034 non-null float64
# game_type                1474090 non-null object
# stand                    1474090 non-null object
# p_throws                 1474090 non-null object
# home_team                1474090 non-null object
# away_team                1474090 non-null object
# type                     1474090 non-null object
# hit_location             327903 non-null float64
# bb_type                  255347 non-null object
# ...

# %%
cap_df.to_pickle("cap_df.pkl")
